# %%
import json
import os
import pathlib
import subprocess

repo_root = pathlib.Path('/workspaces/website')
print('Repo root:', repo_root)
print('Exists:', repo_root.exists())
print('Listing root files:', [p.name for p in repo_root.iterdir() if p.name in ['package.json', 'pnpm-lock.yaml', '.github']])

# %% [markdown]
# # Fix pnpm lockfile override mismatch
#
# This notebook inspects the GitHub Actions workflow, reproduces the `pnpm install` lockfile mismatch, compares `package.json` overrides to `pnpm-lock.yaml`, and updates the lockfile if needed.
